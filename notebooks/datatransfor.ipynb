# %% [markdown]
# we have to do two things
# 1. image similarity so for that we will create emmbeding model and convert image into vector and cheack similarity
# 2. for celibraty identification we will use imagenat or vgg or other to train with our lable metadata tha we will take prediction.

# %% [markdown]
# similarity

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D


#change to image path
train_dir =  '/teamspace/studios/this_studio/visual-search-similarity/train'
validation_dir = '/teamspace/studios/this_studio/visual-search-similarity/validation'
metadata_train = '/teamspace/studios/this_studio/visual-search-similarity/metadata/train_metadata.csv'
metadata_validation = '/teamspace/studios/this_studio/visual-search-similarity/metadata/validation_metadata.csv'


train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(299, 299),
    batch_size=32,
    class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
    validation_dir,
    target_size=(299, 299),
    batch_size=32,
    class_mode='categorical')


base_model = InceptionV3(weights='imagenet', include_top=False)

x = base_model.output
x = GlobalAveragePooling2D()(x)

# Add a fully-connected layer and a logistic layer with the number of classes
num_classes = len(train_generator.class_indices)
x = Dense(1024, activation='relu')(x)
predictions = Dense(num_classes, activation='softmax')(x)

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=10)
# Out:
# 2024-06-16 15:17:54.325944: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-16 15:17:55.203900: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found 1260 images belonging to 17 classes.
# Found 540 images belonging to 17 classes.
# 2024-06-16 15:17:56.947014: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20974 MB memory:  -> device: 0, name: NVIDIA L4, pci bus id: 0000:35:00.0, compute capability: 8.9
# Epoch 1/10
# ...

# %%
model.save('/teamspace/studios/this_studio/visual-search-similarity/model/inception.keras')

# %%
model.summary()

# %%
# Define a model to extract embeddings
embedding_model = Model(inputs=base_model.input, outputs=GlobalAveragePooling2D()(base_model.output))

def get_embedding(model, img_path):
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=(299, 299))
    img_data = tf.keras.preprocessing.image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = tf.keras.applications.inception_v3.preprocess_input(img_data)
    
    embedding = model.predict(img_data)
    return embedding

# Example: Get embedding for an image
embedding = get_embedding(embedding_model, '/teamspace/studios/this_studio/visual-search-similarity/train/Angelina Jolie/001_fe3347c0.jpg')
print(embedding.shape)  # Should be (1, 2048)

# Save embeddings for the entire dataset
import os
import numpy as np

def save_embeddings(directory, model, output_file):
    embeddings = []
    labels = []
    for person in os.listdir(directory):
        person_dir = os.path.join(directory, person)
        if os.path.isdir(person_dir):
            for img_name in os.listdir(person_dir):
                img_path = os.path.join(person_dir, img_name)
                if img_name.lower().endswith(('png', 'jpg', 'jpeg')):
                    embedding = get_embedding(model, img_path)
                    embeddings.append(embedding)
                    labels.append(person)
    embeddings = np.vstack(embeddings)
    np.savez(output_file, embeddings=embeddings, labels=labels)

save_embeddings(train_dir, embedding_model, 'train_embeddings.npz')
save_embeddings(validation_dir, embedding_model, 'validation_embeddings.npz')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# (1, 2048)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# ...

# %%
from numpy.linalg import norm

def cosine_similarity(v1, v2):
    return np.dot(v1, v2) / (norm(v1) * norm(v2))

def find_similar(image_embedding, embeddings, labels, top_k=5):
    similarities = [cosine_similarity(image_embedding, emb) for emb in embeddings]
    sorted_indices = np.argsort(similarities)[::-1]
    return [(labels[idx], similarities[idx]) for idx in sorted_indices[:top_k]]

# Load embeddings
data = np.load('/teamspace/studios/this_studio/train_embeddings.npz')
embeddings = data['embeddings']
labels = data['labels']

# Find similar images
image_embedding = get_embedding(embedding_model, '/teamspace/studios/this_studio/visual-search-similarity/train/Robert Downey Jr/001_a51bb26a.jpg')
similar_images = find_similar(image_embedding, embeddings, labels)

for label, similarity in similar_images:
    print(f'Label: {label}, Similarity: {similarity}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 17
#      14 labels = data['labels']
#      16 # Find similar images
# ---> 17 image_embedding = get_embedding(embedding_model, '/teamspace/studios/this_studio/visual-search-similarity/train/Robert Downey Jr/001_a51bb26a.jpg')
#      18 similar_images = find_similar(image_embedding, embeddings, labels)
#      20 for label, similarity in similar_images:
#
# NameError: name 'get_embedding' is not defined

# %%
import numpy as np
from numpy.linalg import norm

# Function to calculate cosine similarity between two vectors
def cosine_similarity(v1, v2):
    return np.dot(v1, v2) / (norm(v1) * norm(v2))

# Function to find similar images based on cosine similarity
def find_similar(image_embedding, embeddings, labels, top_k=5):
    similarities = [cosine_similarity(image_embedding, emb) for emb in embeddings]
    sorted_indices = np.argsort(similarities)[::-1]
    return [(labels[idx], similarities[idx]) for idx in sorted_indices[:top_k]]

if __name__ == "__main__":
    # Load embeddings and labels from file
    data = np.load('/teamspace/studios/this_studio/train_embeddings.npz')
    embeddings = data['embeddings']
    labels = data['labels']

    # Assuming `image_embedding` is obtained correctly from the query image
    image_embedding = embeddings[0]  # Example: First embedding from the loaded data

    # Find similar images
    similar_images = find_similar(image_embedding, embeddings, labels)

    # Print or process similar images
    for label, similarity in similar_images:
        print(f'Label: {label}, Similarity: {similarity}')
# Out:
# Label: Angelina Jolie, Similarity: 1.0000001192092896
# Label: Scarlett Johansson, Similarity: 0.982925534248352
# Label: Angelina Jolie, Similarity: 0.974856972694397
# Label: Angelina Jolie, Similarity: 0.9722724556922913
# Label: Brad Pitt, Similarity: 0.9696381688117981

# %%
import numpy as np
from numpy.linalg import norm
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import preprocess_input

# Assuming you already have your embedding model loaded
# embedding_model = ...

def load_image(img_path, target_size=(299, 299)):
    
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img_array

def get_embedding(model, img_path):
   
    img = load_image(img_path)
    embedding = model.predict(img)
    return embedding.flatten()

def cosine_similarity(v1, v2):
    
    return np.dot(v1, v2) / (norm(v1) * norm(v2))

def find_similar(image_embedding, embeddings, labels, top_k=5):
    """Find similar images based on cosine similarity."""
    similarities = [cosine_similarity(image_embedding, emb) for emb in embeddings]
    sorted_indices = np.argsort(similarities)[::-1]
    return [(labels[idx], similarities[idx]) for idx in sorted_indices[:top_k]]

if __name__ == "__main__":
    # Load embeddings and labels from file
    data = np.load('/teamspace/studios/this_studio/train_embeddings.npz')
    embeddings = data['embeddings']
    labels = data['labels']

    # Path to the query image
    query_image_path = '/teamspace/studios/this_studio/visual-search-similarity/validation/Hugh Jackman/032_0e6a520a.jpg'  # Replace with the path to your query image

    # Generate embedding for the query image
    image_embedding = get_embedding(embedding_model, query_image_path)

    # Find similar images
    similar_images = find_similar(image_embedding, embeddings, labels)

    # Print similar images
    for label, similarity in similar_images:
        print(f'Label: {label}, Similarity: {similarity}')
# Out:
# 2024-06-16 14:18:46.679054: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-16 14:18:47.529954: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 43
#      40 query_image_path = '/teamspace/studios/this_studio/visual-search-similarity/validation/Hugh Jackman/032_0e6a520a.jpg'  # Replace with the path to your query image
#      42 # Generate embedding for the query image
# ---> 43 image_embedding = get_embedding(embedding_model, query_image_path)
#      45 # Find similar images
# ...

# %%
import numpy as np
from numpy.linalg import norm
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D

# Load InceptionV3 model pre-trained on ImageNet and exclude top layers
base_model = InceptionV3(weights='imagenet', include_top=False)
embedding_model = Model(inputs=base_model.input, outputs=GlobalAveragePooling2D()(base_model.output))

def load_image(img_path, target_size=(299, 299)):
    """Load and preprocess the image."""
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img_array

def get_embedding(model, img_path):
    """Get the embedding of an image using the given model."""
    img = load_image(img_path)
    embedding = model.predict(img)
    return embedding.flatten()

def cosine_similarity(v1, v2):
    """Calculate cosine similarity between two vectors."""
    return np.dot(v1, v2) / (norm(v1) * norm(v2))

def find_similar(image_embedding, embeddings, labels, top_k=5):
    """Find similar images based on cosine similarity."""
    similarities = [cosine_similarity(image_embedding, emb) for emb in embeddings]
    sorted_indices = np.argsort(similarities)[::-1]
    return [(labels[idx], similarities[idx]) for idx in sorted_indices[:top_k]]

if __name__ == "__main__":
    # Load embeddings and labels from file
    data = np.load('/teamspace/studios/this_studio/train_embeddings.npz')
    embeddings = data['embeddings']
    labels = data['labels']

    # Path to the query image
    query_image_path = '/teamspace/studios/this_studio/visual-search-similarity/train/Tom Cruise/001_08212dcd.jpg'  # Replace with the path to your query image

    # Generate embedding for the query image
    image_embedding = get_embedding(embedding_model, query_image_path)

    # Find similar images
    similar_images = find_similar(image_embedding, embeddings, labels)

    # Print similar images
    for label, similarity in similar_images:
        print(f'Label: {label}, Similarity: {similarity}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Label: Denzel Washington, Similarity: 0.460556298494339
# Label: Brad Pitt, Similarity: 0.4417386054992676
# Label: Will Smith, Similarity: 0.42774051427841187
# Label: Nicole Kidman, Similarity: 0.42476990818977356
# Label: Will Smith, Similarity: 0.4115653932094574

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

urls = []

@app.route('/save_url', methods=['POST'])
def save_url():
    url = request.json.get('url')
    if url:
        urls.append(url)
        return jsonify({'message': 'URL saved!', 'urls': urls})
    return jsonify({'error': 'No URL provided'}), 400

@app.route('/get_urls', methods=['GET'])
def get_urls():
    return jsonify({'urls': urls})

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5000)
